# %%
import urllib.request

# %%
# mountains
filename = 'Imagenet_mountains.txt'
with open(filename) as f:
    photo_urls = f.readlines()

# %%
photo_urls = [i.strip() for i in photo_urls]

# %%
path = 'data/train/mountains/'
for url in photo_urls:
    filename = url.split('/')[-1]
    try:
        urllib.request.urlretrieve(url, path + filename)
    except:
        print(url)
        continue
# Out:
# http://www.yemenembassy.org.uk/About%20Yemen/Images/yemen05.jpg
# http://www.lancs.ac.uk/ug/howarthl/Mountain%20Top.jpg
# http://www.hayesphotoweb.com/nature/MtnHorse.jpg
# http://www.cctsbeijing.com/china_guide/images/china_geography_mountain1.jpg
# http://www.patagoniagliding.org.ar/Nov04/Jantar%20Cordillera-26.jpg
# http://www.northstarcabin.com/parkway.jpg
# http://www.scanno.org/images/scanno_montagne_0603_01.jpg
# http://www.hombreynaturaleza.com/Fotos/SanJose2.jpg
# http://www.sinaimg.cn/ty/o/p/2007-07-26/U1974P6T12D3063381F44DT20070726105952.jpg
# http://www.fredmiranda.com/A10_Kelvin/images/Xiling%20Gorge2.jpg
# http://images.myareaguide.com/aps/op/wrst.jpg
# http://lh5.ggpht.com/_73a_zWmZkCc/RXVIXufZMLI/AAAAAAAAB7Q/OJ-4tz6aHDQ/DSC01370.JPG
# http://blog.elrincondeltrotamundos.com/wp-content/uploads/2007/06/SIERRA%20ZAPATERO0%2011.jpg
# http://dhzmedia.ca/sites/dhzmedia/uploads/MountainRange_SkiHill_FHS_L.gif
# ...

# %%
# buildings
filename = 'Imagenet_buildings.txt'
with open(filename) as f:
    photo_urls = f.readlines()

# %%
photo_urls = [i.strip() for i in photo_urls]

# %%
path = 'data/train/buildings/'
for url in photo_urls:
    filename = url.split('/')[-1]
    try:
        urllib.request.urlretrieve(url, path + filename)
    except:
        print(url)
        continue
# Out:
# http://www.arikiart.com/fine-art-photography/construction/mclane/photos/Construction-Crane-2.jpg
# http://www.stancraftboats.com/wooden_boat_images/boat_construction_01.jpg
# http://www.capetown.gov.za/en/PublishingImages/News%20Images/Next_Phase_Stadium_construction.jpg
# http://www.nap.usace.army.mil/sb/bmiavd/dam_construction.jpg
# http://www.puertoviejoskies.com/galerias/4/construction_status_and_news-1.jpg
# http://www.actioncenter.org/images/underconstruction.jpg
# http://cardinal-services.com/images/payrollpics/construction.jpg
# http://www.rics.org/NR/rdonlyres/0642A93B-C0BF-48DD-BCB9-BF5592EA4F02/0/rics10.png
# http://drsi.net/photos/construction1.jpg
# http://www.ctemploymentlawblog.com/construction.jpg
# http://www.seattletimescompany.com/nwretailnews/images/housingconstruction.jpg
# http://www.fos-s.com/website/foss/assets/images/projectadvimages/construction_foto4.jpg
# http://www.iio.on.ca/images/steel%20structure.jpg
# http://www.arbint.co.uk/images/Construction.jpg
# ...

# %%
# streams
filename = 'Imagenet_streams.txt'
with open(filename) as f:
    photo_urls = f.readlines()

# %%
photo_urls = [i.strip() for i in photo_urls]

# %%
path = 'data/train/streams/'
for url in photo_urls:
    filename = url.split('/')[-1]
    try:
        urllib.request.urlretrieve(url, path + filename)
    except:
        print(url)
        continue
# Out:
# http://johnnorvell.net/photogallery/albums/Death_Valley_2005/Death_Valley_creek_bed_near_Harry_Wade_Rd.jpg
# http://santanoniclub.com/gallery/albums/Santanoni-Pictures/Streambed_2.jpg
# http://laeren.zoggins.net/japan/galleries/pics/osaka/kyoto-kinkakuji-dry_streambed.jpg
# http://travel.mongabay.com/tanzania/600/tz_elf_0532.jpg
# http://3dparks.wr.usgs.gov/2007/grandcanyon/thumbs/GRCA4003.jpg
# http://www.brdlandscape.com/pics/dry_streambeds/Streambed-Dry_WhitCble.jpg
# http://scf.rncan.gc.ca/images/4491/450
# http://www.pvadventures.com/down%20the%20stream%20bed.jpg
# http://www.envirodesign.on.ca/images/gallery/garden/g6a.jpg
# http://www.malenytropicalretreat.com/images/obiobi-creek-lge.jpg
# http://www.shoalhaven-landcare.asn.au/images/cs0003e.jpg
# http://www.utahoutdooractivities.com/maplebox6.jpg
# http://www.clemensandassociates.com/streambed4.jpg
# http://www.fabiopani.it/albums/nature/aaj_6.jpg
# http://geoimages.berkeley.edu/Geoimages/BainCalif/cal400/coppore.jpg
# ...
